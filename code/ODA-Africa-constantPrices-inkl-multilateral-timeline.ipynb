# %%
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt
import altair as alt
from vega_datasets import data

# %matplotlib inline
pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

pd.set_option('display.float_format', lambda x: '%.3f' % x)

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# ## Definitions
#
# **Research ODA definition:** "Official Development Assistance (ODA) is the term used by Development Assistance Committee (DAC) members to refer to what most people would call aid. To be counted as ODA, public money must be given outright or loaned on concessional (non-commercial) terms, and be used to support the welfare or development of developing countries." (Source FAQ page, more details on [definition & coverage](https://www.oecd.org/dac/financing-sustainable-development/development-finance-standards/officialdevelopmentassistancedefinitionandcoverage.htm))
#
# ![ExampleODAtypes](resources/ADV2020xls-Screenshot-ODAtypes.png)
#
# **OECD ODA recipients** The DAC List of ODA Recipients shows all countries and territories eligible to receive official development assistance (ODA). These consist of all low and middle income countries based on gross national income (GNI) per capita as published by the World Bank, with the exception of G8 members, EU members, and countries with a firm date for entry into the EU. The list also includes all of the Least Developed Countries (LDCs) as defined by the United Nations (UN). The DAC revises the list every three years. Countries that have exceeded the high-income threshold for three consecutive years at the time of the review are removed. (...) The next review of the DAC List will take place in 2023. ([Source](https://www.oecd.org/dac/financing-sustainable-development/development-finance-standards/daclist.htm))
#
# **DAC** Development Assistance Committee
#
# **Bilateral aid** represents flows from official (government) sources directly to official sources in the recipient country.
#
# **Multilateral aid** represents core contributions from official (government) sources to multilateral agencies where it is then used to fund the multilateral agencies’ own programmes.
#
# In some cases, a donor can contract with a multilateral agency to deliver a programme or project on its behalf in a recipient country. Such cases are typically counted as bilateral flows and are often referred to as Bi/Multi.
#
# **Official donors** DAC + Non-DAC + multilateral; excludes private donors which according to OECD *should* be excluded

# %% [markdown]
# ## Conversion
# ### between constant USD 2017 (Chinese data) und current prices million USD (OECD data)
#
# * **Current prices to constant ones** *The following table shows the annual rates of the Consumer Price Index. To convert current dollars of any year to constant dollars, divide them by the index of that year and multiply them by the index of the base year you choose (remember that the numerator contains the index value of the year you want to move to). For example, using this index, `$10,000 in 1997 would be 12,622 in 2008 constant dollars ($10,000 × 114.1/  90.4 = $12,622)`.* Source: [Canadian Statistics Office](https://www150.statcan.gc.ca/n1/pub/75f0011x/2011001/notes/analytical-analytiques-eng.htm)
#     * is the Consumer Price Index different for each country or is there a global one?
#
#
# * ***Current dollars** is a term describing income in the year in which a person, household, or family receives it. For example, the income someone received in 1989 unadjusted for inflation is in current dollars.**Constant or real dollars** are terms describing income after adjustment for inflation. The Dictionary of Business and Economics defines constant dollar values and real income as shown below.* Source: [US Census Bureau](https://www.census.gov/topics/income-poverty/income/guidance/current-vs-constant-dollars.html)

# %% [markdown]
# # Checks

# %% [markdown]
# ## In 2020, are there African countries *not* eligible for ODA?

# %%
eligible_countries = pd.read_csv('../data/OECD-ODA-eligible-country-2020.csv')

eligible_countries.head()
# Out:
#                    ODA_eligible_country iso3code  numericISOcode eligibility
# 0                           Afghanistan      AFG           4.000         yes
# 1  Democratic Peoples Republic of Korea      PRK         408.000         yes
# 2                               Armenia      ARM          51.000         yes
# 3                               Albania      ALB           8.000         yes
# 4                                Angola      AGO          24.000         yes

# %%
countries = alt.topo_feature(data.world_110m.url, "countries")
countries
# Out:
# UrlData({
#   format: TopoDataFormat({
#     feature: 'countries',
#     type: 'topojson'
#   }),
#   url: 'https://cdn.jsdelivr.net/npm/vega-datasets@v1.29.0/data/world-110m.json'
# })

# %%
import altair as alt
from vega_datasets import data

countries = alt.topo_feature(data.world_110m.url, "countries")

projection_type="naturalEarth1"
scale_value=240
center_values=[25,10]

base = alt.Chart(countries).mark_geoshape(
    fill='#D8DDE2',
    stroke='white'
).properties(
    width=1200,
    height=800,
).project(
    type=projection_type,
    center=center_values,
    scale=scale_value
)

chart = alt.Chart(countries).mark_geoshape().encode(
    alt.Color('eligibility:N', type ='ordinal', scale=alt.Scale(domain=['yes'],range=["#00A5FF"])),
    tooltip=["ODA_eligible_country:N", 'eligibility:N']
).transform_lookup(
    lookup="id",
    from_=alt.LookupData(eligible_countries,'numericISOcode',['ODA_eligible_country','eligibility'])
).project(
    type=projection_type,
    center=center_values,
    scale=scale_value
).properties(
    width=1200,
    height=800,
    title='Countries eligible for ODA in 2020'
)

eligble_map = base + chart
eligble_map
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # DATA INSPECTION

# %%
df = pd.DataFrame()

for year in range(2002,2020,1):
    filename = '../data/ODA-yearly/ODA-'+str(year)+'-DAC2a.csv'
    df_temp = pd.read_csv(filename)
    df_temp['year'] = year
    df = pd.concat([df, df_temp])

df = df.drop('FakeColumn', axis=1)
df.head()
# Out:
#                             Recipient  Official Donors, Total  \
# 0                      All Recipients                     NaN
# 1     All Developing Countries, Total               60966.210
# 2  All Multilateral Recipients, Total               18065.250
# 3                       Africa, Total               21368.300
# 4              North of Sahara, Total                2106.580
#
#    DAC Countries, Total  Non-DAC Countries, Total  \
# 0             58654.230                  3264.430
# 1             41012.360                  3139.820
# 2             17641.870                   124.610
# 3             13379.280                   239.550
# 4              1640.120                    93.300
#
#    Multilateral Agencies, Total  Private Donors, Total  Australia  Austria  \
# 0                     17112.800                    NaN    988.740  520.130
# 1                     16814.030                    NaN    773.670  364.240
# 2                       298.770                    NaN    215.070  155.890
# 3                      7749.470                    NaN     28.980  141.540
# 4                       373.160                    NaN      3.260   21.500
#
#    Belgium   Canada  Czech Republic  Denmark  Finland   France  Germany  \
# 0 1071.510 2004.280          45.430 1643.240  462.200 5486.170 5324.410
# 1  711.490 1500.660          31.310 1038.290  251.330 3615.000 3327.840
# 2  360.020  503.620          14.120  604.950  210.870 1871.170 1996.570
# 3  362.740  387.830           1.390  407.720   91.350 2601.680 1007.440
# 4    3.570   13.670           0.230   15.190    5.390  445.550   72.380
#
#    Greece  Hungary  Iceland  Ireland    Italy    Japan   Korea  Luxembourg  \
# 0 276.170      NaN   12.650  397.780 2332.130 9282.950 278.750     146.760
# 1 106.990      NaN    4.810  267.160 1006.560 6692.270 206.730     115.720
# 2 169.180      NaN    7.840  130.620 1325.570 2590.680  72.020      31.040
# 3   2.250      NaN    4.810  190.680  810.360  700.210   5.630      54.080
# 4   0.740      NaN      NaN    0.080    6.660  115.290   3.040       4.000
#
#    Netherlands  New Zealand   Norway  Poland  Portugal  Slovak Republic  \
# 0     3338.020      121.820 1696.090  14.260   322.580            6.680
# 1     2448.630       91.690 1145.140   8.890   186.070            3.720
# 2      889.390       30.130  550.950   5.370   136.510            2.960
# 3      955.410        6.280  451.970   0.600    97.080            0.280
# 4       15.390        0.020    4.070   0.150     0.770            0.030
#
#    Slovenia    Spain   Sweden  Switzerland  United Kingdom  United States  \
# 0       NaN 1712.300 2011.060      938.890        4929.160      13290.070
# 1       NaN  998.470 1270.610      764.530        3510.440      10570.100
# 2       NaN  713.830  740.450      174.360        1418.720       2719.970
# 3       NaN  231.190  408.930      187.380        1052.250       3189.220
# 4       NaN   67.740    4.410        7.880          12.180        816.930
#
#    EU Institutions  Azerbaijan  Bulgaria  Croatia  Cyprus  Estonia  Israel  \
# 0         5448.120         NaN       NaN      NaN     NaN    1.250 130.890
# 1         5149.960         NaN       NaN      NaN     NaN    0.200 124.410
# 2          298.160         NaN       NaN      NaN     NaN    1.050   6.480
# 3         2102.510         NaN       NaN      NaN     NaN      NaN  32.740
# 4          298.570         NaN       NaN      NaN     NaN      NaN   0.600
#
#    Kazakhstan  Kuwait  Latvia  Liechtenstein  Lithuania  Malta  Qatar  \
# 0         NaN  20.380   1.500            NaN      1.640    NaN    NaN
# 1         NaN  20.380   0.060            NaN      0.500    NaN    NaN
# 2         NaN     NaN   1.440            NaN      1.140    NaN    NaN
# 3         NaN   1.980     NaN            NaN      0.020    NaN    NaN
# 4         NaN -18.180     NaN            NaN      0.000    NaN    NaN
#
#    Romania  Russia  Saudi Arabia  Chinese Taipei  Thailand  Timor-Leste  \
# 0      NaN     NaN      2477.750             NaN       NaN          NaN
# 1      NaN     NaN      2410.050             NaN       NaN          NaN
# 2      NaN     NaN        67.700             NaN       NaN          NaN
# 3      NaN     NaN        17.810             NaN       NaN          NaN
# 4      NaN     NaN           NaN             NaN       NaN          NaN
#
#    Turkey  United Arab Emirates  Other donor countries  \
# 0  72.960               558.060                    NaN
# 1  26.680               557.540                    NaN
# 2  46.280                 0.520                    NaN
# 3   0.100               186.900                    NaN
# 4   0.020               110.860                    NaN
#
#    International Monetary Fund, Total  IMF (Concessional Trust Funds)  \
# 0                             901.620                         901.620
# 1                             901.620                         901.620
# 2                                 NaN                             NaN
# 3                             691.930                         691.930
# 4                                 NaN                             NaN
#
#    Regional Development Banks, Total  African Development Bank, Total  \
# 0                            876.150                          714.560
# 1                            875.540                          714.560
# 2                              0.610                              NaN
# 3                            735.630                          714.560
# 4                              3.790                            5.090
#
#    African Development Bank [AfDB]  African Development Fund [AfDF]  \
# 0                           99.040                          615.520
# 1                           99.040                          615.520
# 2                              NaN                              NaN
# 3                           99.040                          615.520
# 4                              NaN                            5.090
#
#    Asian Development Bank, Total  Asian Development Bank [AsDB]  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    Inter-American Development Bank, Total  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Inter-American Development Bank [IDB]  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Asian Infrastructure Investment Bank [AIIB]  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Caribbean Development Bank [CarDB]  \
# 0                              62.800
# 1                              62.800
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Council of Europe Development Bank [CEB]  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    European Bank for Reconstruction and Development [EBRD]  \
# 0                                             43.900
# 1                                             43.900
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Islamic Development Bank [IsDB]  United Nations, Total  \
# 0                           54.890               3142.650
# 1                           54.280               3142.650
# 2                            0.610                    NaN
# 3                           21.070               1163.660
# 4                           -1.300                 37.950
#
#    Food and Agriculture Organisation [FAO]  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    International Atomic Energy Agency [IAEA]    IFAD  \
# 0                                        NaN 148.470
# 1                                        NaN 148.470
# 2                                        NaN     NaN
# 3                                        NaN  64.830
# 4                                        NaN   0.330
#
#    International Labour Organisation [ILO]  UNAIDS    UNDP  UNECE  UNEP  \
# 0                                      NaN     NaN 274.680    NaN   NaN
# 1                                      NaN     NaN 274.680    NaN   NaN
# 2                                      NaN     NaN     NaN    NaN   NaN
# 3                                      NaN     NaN 136.530    NaN   NaN
# 4                                      NaN     NaN   3.710    NaN   NaN
#
#     UNFPA   UNHCR  UNICEF  UN Institute for Disarmament Research [UNIDIR]  \
# 0 310.170 633.490 566.870                                             NaN
# 1 310.170 633.490 566.870                                             NaN
# 2     NaN     NaN     NaN                                             NaN
# 3 102.430 298.960 174.710                                             NaN
# 4   3.680   7.520   5.780                                             NaN
#
#    UN Peacebuilding Fund [UNPBF]   UNRWA    UNTA     WFP  \
# 0                            NaN 392.200 466.160 350.610
# 1                            NaN 392.200 466.160 350.610
# 2                            NaN     NaN     NaN     NaN
# 3                            NaN     NaN 160.670 225.530
# 4                            NaN     NaN   7.760   9.170
#
#    World Health Organisation [WHO]  World Tourism Organisation [UNWTO]  \
# 0                              NaN                                 NaN
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
#
#    World Bank Group, Total  World Bank, Total  \
# 0                 6163.420           6163.420
# 1                 6163.420           6163.420
# 2                      NaN                NaN
# 3                 2879.840           2879.840
# 4                   17.040             17.040
#
#    International Bank for Reconstruction and Development [IBRD]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    International Development Association [IDA]  \
# 0                                     6163.420
# 1                                     6163.420
# 2                                          NaN
# 3                                     2879.840
# 4                                       17.040
#
#    International Finance Corporation [IFC]  Other Multilateral, Total  \
# 0                                      NaN                    580.840
# 1                                      NaN                    580.840
# 2                                      NaN                        NaN
# 3                                      NaN                    175.900
# 4                                      NaN                     15.810
#
#    Adaptation Fund  Arab Bank for Economic Development in Africa [BADEA]  \
# 0              NaN                                                NaN
# 1              NaN                                                NaN
# 2              NaN                                                NaN
# 3              NaN                                                NaN
# 4              NaN                                                NaN
#
#    Arab Fund (AFESD)  Center of Excellence in Finance [CEF]  \
# 0                NaN                                    NaN
# 1                NaN                                    NaN
# 2                NaN                                    NaN
# 3                NaN                                    NaN
# 4                NaN                                    NaN
#
#    Central Emergency Response Fund [CERF]  Climate Investment Funds [CIF]  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
#
#    Global Alliance for Vaccines and Immunization [GAVI]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Global Environment Facility [GEF]  Global Fund  \
# 0                            402.950          NaN
# 1                            402.950          NaN
# 2                                NaN          NaN
# 3                             92.050          NaN
# 4                             17.000          NaN
#
#    Global Green Growth Institute [GGGI]  Green Climate Fund [GCF]  \
# 0                                   NaN                       NaN
# 1                                   NaN                       NaN
# 2                                   NaN                       NaN
# 3                                   NaN                       NaN
# 4                                   NaN                       NaN
#
#    Montreal Protocol  Nordic Development Fund [NDF]  \
# 0             59.970                         32.770
# 1             59.970                         32.770
# 2                NaN                            NaN
# 3              0.470                         19.630
# 4              0.470                          1.210
#
#    OPEC Fund for International Development [OPEC Fund]  OSCE  \
# 0                                             85.150     NaN
# 1                                             85.150     NaN
# 2                                                NaN     NaN
# 3                                             63.750     NaN
# 4                                             -2.870     NaN
#
#    Other Multilaterals  Arcadia Fund  Arcus Foundation  \
# 0                  NaN           NaN               NaN
# 1                  NaN           NaN               NaN
# 2                  NaN           NaN               NaN
# 3                  NaN           NaN               NaN
# 4                  NaN           NaN               NaN
#
#    BBVA Microfinance Foundation  Bernard van Leer Foundation  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#    Bill & Melinda Gates Foundation  Carnegie Corporation of New York  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    Charity Projects Ltd (Comic Relief)  Children's Investment Fund Foundation  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    Citi Foundation  Conrad N. Hilton Foundation  \
# 0              NaN                          NaN
# 1              NaN                          NaN
# 2              NaN                          NaN
# 3              NaN                          NaN
# 4              NaN                          NaN
#
#    David & Lucile Packard Foundation  Ford Foundation  \
# 0                                NaN              NaN
# 1                                NaN              NaN
# 2                                NaN              NaN
# 3                                NaN              NaN
# 4                                NaN              NaN
#
#    Gatsby Charitable Foundation  Gordon and Betty Moore Foundation  \
# 0                           NaN                                NaN
# 1                           NaN                                NaN
# 2                           NaN                                NaN
# 3                           NaN                                NaN
# 4                           NaN                                NaN
#
#    Grameen Crédit Agricole Foundation  H&M Foundation  IKEA Foundation  \
# 0                                 NaN             NaN              NaN
# 1                                 NaN             NaN              NaN
# 2                                 NaN             NaN              NaN
# 3                                 NaN             NaN              NaN
# 4                                 NaN             NaN              NaN
#
#    Jacobs Foundation  John D. & Catherine T. MacArthur Foundation  \
# 0                NaN                                          NaN
# 1                NaN                                          NaN
# 2                NaN                                          NaN
# 3                NaN                                          NaN
# 4                NaN                                          NaN
#
#    La Caixa Banking Foundation  Laudes Foundation  LEGO Foundation  \
# 0                          NaN                NaN              NaN
# 1                          NaN                NaN              NaN
# 2                          NaN                NaN              NaN
# 3                          NaN                NaN              NaN
# 4                          NaN                NaN              NaN
#
#    Margaret A. Cargill Foundation  MasterCard Foundation  MAVA Foundation  \
# 0                             NaN                    NaN              NaN
# 1                             NaN                    NaN              NaN
# 2                             NaN                    NaN              NaN
# 3                             NaN                    NaN              NaN
# 4                             NaN                    NaN              NaN
#
#    McKnight Foundation  MetLife Foundation  Michael & Susan Dell Foundation  \
# 0                  NaN                 NaN                              NaN
# 1                  NaN                 NaN                              NaN
# 2                  NaN                 NaN                              NaN
# 3                  NaN                 NaN                              NaN
# 4                  NaN                 NaN                              NaN
#
#    Oak Foundation  Omidyar Network Fund, Inc.  Rockefeller Foundation  \
# 0             NaN                         NaN                     NaN
# 1             NaN                         NaN                     NaN
# 2             NaN                         NaN                     NaN
# 3             NaN                         NaN                     NaN
# 4             NaN                         NaN                     NaN
#
#    Wellcome Trust  William & Flora Hewlett Foundation  \
# 0             NaN                                 NaN
# 1             NaN                                 NaN
# 2             NaN                                 NaN
# 3             NaN                                 NaN
# 4             NaN                                 NaN
#
#    World Diabetes Foundation  Dutch Postcode Lottery  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
#
#    Norwegian Postcode Lottery  People's Postcode Lottery  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#    Swedish Postcode Lottery  G7 Countries, Total  DAC-EU Countries, Total  \
# 0                       NaN            42649.170                30039.990
# 1                       NaN            30222.870                19262.760
# 2                       NaN            12426.300                10777.230
# 3                       NaN             9748.990                 8416.970
# 4                       NaN             1482.660                  675.960
#
#    United Postcode Lotteries, Total  year  Donor(s) Unnamed: 0
# 0                               NaN  2002       NaN        NaN
# 1                               NaN  2002       NaN        NaN
# 2                               NaN  2002       NaN        NaN
# 3                               NaN  2002       NaN        NaN
# 4                               NaN  2002       NaN        NaN

# %%
df_melted = df.melt(id_vars=['Recipient','year'])
df_melted.head()
# Out:
#                             Recipient  year                variable     value
# 0                      All Recipients  2002  Official Donors, Total       NaN
# 1     All Developing Countries, Total  2002  Official Donors, Total 60966.210
# 2  All Multilateral Recipients, Total  2002  Official Donors, Total 18065.250
# 3                       Africa, Total  2002  Official Donors, Total 21368.300
# 4              North of Sahara, Total  2002  Official Donors, Total  2106.580

# %%
df_melted[(df_melted['Recipient']=='Afghanistan')&(df_melted['variable']=='Germany')]
# Out:
#          Recipient  year variable   value
# 64390  Afghanistan  2002  Germany  92.570
# 64665  Afghanistan  2003  Germany  82.100
# 64940  Afghanistan  2004  Germany   9.610
# 65215  Afghanistan  2005  Germany  17.280
# 65490  Afghanistan  2006  Germany  10.910
# 65765  Afghanistan  2007  Germany  17.250
# 66040  Afghanistan  2008  Germany  10.130
# 66315  Afghanistan  2009  Germany  17.970
# 66865  Afghanistan  2011  Germany 539.300
# 67140  Afghanistan  2012  Germany 515.540
# 67415  Afghanistan  2013  Germany 548.690
# 67690  Afghanistan  2014  Germany 529.390
# 67965  Afghanistan  2015  Germany 362.070
# 68240  Afghanistan  2016  Germany 502.840
# 68515  Afghanistan  2017  Germany 478.430
# 68790  Afghanistan  2018  Germany 438.050
# 69065  Afghanistan  2019  Germany 409.230

# %%
supp1 = pd.read_csv('../data/ODA-supplementary-donortype.csv')
supp1.head()
# Out:
#                           donor donor_type
# 0        Official Donors, Total    summary
# 1          DAC Countries, Total    summary
# 2      Non-DAC Countries, Total    summary
# 3  Multilateral Agencies, Total    summary
# 4         Private Donors, Total    summary

# %%
df_melted = df_melted.merge(supp1, left_on='variable', right_on='donor')
df_melted.head()
# Out:
#                             Recipient  year                variable     value  \
# 0                      All Recipients  2002  Official Donors, Total       NaN
# 1     All Developing Countries, Total  2002  Official Donors, Total 60966.210
# 2  All Multilateral Recipients, Total  2002  Official Donors, Total 18065.250
# 3                       Africa, Total  2002  Official Donors, Total 21368.300
# 4              North of Sahara, Total  2002  Official Donors, Total  2106.580
#
#                     donor donor_type
# 0  Official Donors, Total    summary
# 1  Official Donors, Total    summary
# 2  Official Donors, Total    summary
# 3  Official Donors, Total    summary
# 4  Official Donors, Total    summary

# %%
df_melted = df_melted[['Recipient', 'year','value', 'donor', 'donor_type']]
df_melted.columns= (['Recipient', 'year','currentPrices_Million_USD', 'donor', 'donor_type'])

# %%
df_melted.head()
# Out:
#                             Recipient  year currentPrices_Million_USD  \
# 0                      All Recipients  2002                       NaN
# 1     All Developing Countries, Total  2002                 60966.210
# 2  All Multilateral Recipients, Total  2002                 18065.250
# 3                       Africa, Total  2002                 21368.300
# 4              North of Sahara, Total  2002                  2106.580
#
#                     donor donor_type
# 0  Official Donors, Total    summary
# 1  Official Donors, Total    summary
# 2  Official Donors, Total    summary
# 3  Official Donors, Total    summary
# 4  Official Donors, Total    summary

# %%
overview_developingCountries = df_melted[(df_melted['donor_type']=='summary')&(df_melted['donor']=='Official Donors, Total')&(df_melted['Recipient']=='All Developing Countries, Total')]
overview_developingCountries
# Out:
#                             Recipient  year currentPrices_Million_USD  \
# 1     All Developing Countries, Total  2002                 60966.210
# 276   All Developing Countries, Total  2003                 70525.190
# 551   All Developing Countries, Total  2004                 54785.710
# 826   All Developing Countries, Total  2005                 83112.970
# 1101  All Developing Countries, Total  2006                 77622.450
# 1376  All Developing Countries, Total  2007                 73734.610
# 1651  All Developing Countries, Total  2008                 87128.240
# 1926  All Developing Countries, Total  2009                 83968.370
# 2476  All Developing Countries, Total  2011                139449.770
# 2751  All Developing Countries, Total  2012                133751.600
# 3026  All Developing Countries, Total  2013                151137.930
# 3301  All Developing Countries, Total  2014                161729.790
# 3576  All Developing Countries, Total  2015                146741.890
# 3851  All Developing Countries, Total  2016                158810.930
# 4126  All Developing Countries, Total  2017                165089.850
# 4401  All Developing Countries, Total  2018                167559.850
# 4676  All Developing Countries, Total  2019                163504.360
#
#                        donor donor_type
# 1     Official Donors, Total    summary
# 276   Official Donors, Total    summary
# 551   Official Donors, Total    summary
# 826   Official Donors, Total    summary
# 1101  Official Donors, Total    summary
# 1376  Official Donors, Total    summary
# 1651  Official Donors, Total    summary
# 1926  Official Donors, Total    summary
# 2476  Official Donors, Total    summary
# 2751  Official Donors, Total    summary
# 3026  Official Donors, Total    summary
# 3301  Official Donors, Total    summary
# 3576  Official Donors, Total    summary
# 3851  Official Donors, Total    summary
# 4126  Official Donors, Total    summary
# 4401  Official Donors, Total    summary
# 4676  Official Donors, Total    summary

# %%
overview_africa = df_melted[(df_melted['donor_type']=='summary')&(df_melted['donor']=='Official Donors, Total')&(df_melted['Recipient']=='Africa, Total')]

# %%
overview_ssa_africa = df_melted[(df_melted['donor_type']=='summary')&(df_melted['donor']=='Official Donors, Total')&(df_melted['Recipient']=='South of Sahara, Total')]

# %%
all_devC=alt.Chart(overview_developingCountries).mark_bar(color='#6D7780').encode(
    x='year:N',
    y='currentPrices_Million_USD:Q'
)

african_c=alt.Chart(overview_africa).mark_bar(color='#002D5A').encode(
    x='year:N',
    y='currentPrices_Million_USD:Q'
)

ssa_c = alt.Chart(overview_ssa_africa).mark_bar(color='#00A5FF').encode(
    x='year:N',
    y='currentPrices_Million_USD:Q'
)

layered = alt.layer(all_devC, african_c, ssa_c)

layered.properties(width = 300)
# Out:
# alt.LayerChart(...)

# %%
df_melted['donor_type'].value_counts()
# Out:
# bilateral       257400
# private         198000
# multilateral    133650
# subgroup        133650
# summary          34650
# Name: donor_type, dtype: int64

# %%
df_melted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 757350 entries, 0 to 757349
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Recipient                  715275 non-null  object
#  1   year                       757350 non-null  int64
#  2   currentPrices_Million_USD  203751 non-null  object
#  3   donor                      757350 non-null  object
#  4   donor_type                 757350 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 34.7+ MB

# %%
donor_types = df_melted.groupby(by='donor_type')['currentPrices_Million_USD'].sum().reset_index()

# %%
donor_types=donor_types.drop(index = 3)

# %%
donor_types
# Out:
#      donor_type currentPrices_Million_USD
# 0     bilateral              15703295.850
# 1  multilateral               3189056.010
# 2       private              16194914.710
# 4       summary              31871263.640

# %%
sum_money_OECD_donors = donor_types['currentPrices_Million_USD'].sum()

# %%
donor_types['share_donorType'] = [donor_money / sum_money_OECD_donors for donor_money in donor_types['currentPrices_Million_USD']]

# %%
donor_types
# Out:
#      donor_type currentPrices_Million_USD  share_donorType
# 0     bilateral              15703295.850            0.235
# 1  multilateral               3189056.010            0.048
# 2       private              16194914.710            0.242
# 4       summary              31871263.640            0.476

# %%
alt.Chart(donor_types).mark_bar(height = 100).encode(
    alt.X('sum(currentPrices_Million_USD):Q',stack='normalize'),
    color='donor_type:N'
).properties(
    height=100
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Chinese data

# %%
cf = pd.read_csv('../data/AidData_excerpt_aggregates_all_years.csv', delimiter=';')
cf.head()
# Out:
#    \AidData TUFF Project ID Recommended For Aggregates Umbrella  \
# 0                     53631                        Yes       No
# 1                     53632                        Yes       No
# 2                     53633                        Yes       No
# 3                     53634                        Yes       No
# 4                     53636                        Yes       No
#
#               Financier Country    Recipient Recipient Region  \
# 0  China (People's Republic of)  Afghanistan             Asia
# 1  China (People's Republic of)  Afghanistan             Asia
# 2  China (People's Republic of)  Afghanistan             Asia
# 3  China (People's Republic of)  Afghanistan             Asia
# 4  China (People's Republic of)  Afghanistan             Asia
#
#    Commitment Year                                              Title  \
# 0             2017  China provides humanitarian aid to Afghanistan...
# 1             2017       China donates equipment to Kabul University
# 2             2017  China donates $1 million USD to UNHCR for huma...
# 3             2017  Chinese Government provides RMB 180 million gr...
# 4             2017  China donates desks and chairs to China-Afghan...
#
#        Status            Intent Flow Type Concessional Flow Class  \
# 0  Completion       Development     Grant          Yes   ODA-like
# 1  Completion       Development     Grant          Yes   ODA-like
# 2  Completion       Development     Grant          Yes   ODA-like
# 3  Completion       Development     Grant          Yes   ODA-like
# 4  Completion  Representational     Grant          Yes   OOF-like
#
#    Sector Code         Sector Name  \
# 0          720  EMERGENCY RESPONSE
# 1          110           EDUCATION
# 2          720  EMERGENCY RESPONSE
# 3          110           EDUCATION
# 4          110           EDUCATION
#
#                              Funding Agencies Funding Agencies Type  \
# 0  Unspecified Chinese Government Institution     Government Agency
# 1  Unspecified Chinese Government Institution     Government Agency
# 2  Unspecified Chinese Government Institution     Government Agency
# 3                  China Ministry of Commerce     Government Agency
# 4                             Chinese Embassy     Government Agency
#
#    Amount (Original Currency) Original Currency  Amount (Constant USD2017)  \
# 0               137100000.000               AFN                2015410.812
# 1                         NaN               NaN                        NaN
# 2                 1000000.000               USD                1000000.000
# 3                18000000.000               CNY                2663728.108
# 4                         NaN               NaN                        NaN
#
#    Amount (Nominal)
# 0       2015410.812
# 1               NaN
# 2       1000000.000
# 3       2663728.108
# 4               NaN

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10849 entries, 0 to 10848
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   \AidData TUFF Project ID    10849 non-null  int64
#  1   Recommended For Aggregates  10849 non-null  object
#  2   Umbrella                    10849 non-null  object
#  3   Financier Country           10849 non-null  object
#  4   Recipient                   10849 non-null  object
#  5   Recipient Region            10849 non-null  object
#  6   Commitment Year             10849 non-null  int64
#  7   Title                       10849 non-null  object
#  8   Status                      10849 non-null  object
#  9   Intent                      10849 non-null  object
#  10  Flow Type                   10849 non-null  object
#  11  Concessional                10849 non-null  object
#  12  Flow Class                  10849 non-null  object
#  13  Sector Code                 10849 non-null  int64
#  14  Sector Name                 10849 non-null  object
#  15  Funding Agencies            10849 non-null  object
#  16  Funding Agencies Type       10849 non-null  object
#  17  Amount (Original Currency)  6543 non-null   float64
#  18  Original Currency           6543 non-null   object
#  19  Amount (Constant USD2017)   6543 non-null   float64
#  20  Amount (Nominal)            6543 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Chinese financying by flow type

# %%
cf['Flow Class'].value_counts()
# Out:
# ODA-like                    7567
# OOF-like                    2781
# Vague (Official Finance)     501
# Name: Flow Class, dtype: int64

# %%
cf.groupby(by='Flow Class')['Amount (Constant USD2017)'].sum()
# Out:
# Flow Class
# ODA-like                   100558302427.056
# OOF-like                   681961752028.526
# Vague (Official Finance)    60373239964.850
# Name: Amount (Constant USD2017), dtype: float64

# %%
cf_flowTypes = cf.groupby(by='Flow Class')['Amount (Constant USD2017)'].sum().reset_index()

# %%
cf_flowTypes_sum = cf_flowTypes['Amount (Constant USD2017)'].sum()

# %%
cf_flowTypes['share_pct_flowType'] = [flow_type_amount / cf_flowTypes_sum for flow_type_amount in cf_flowTypes['Amount (Constant USD2017)'] ]

# %%
cf_flowTypes
# Out:
#                  Flow Class  Amount (Constant USD2017)  share_pct_flowType
# 0                  ODA-like           100558302427.056               0.119
# 1                  OOF-like           681961752028.526               0.809
# 2  Vague (Official Finance)            60373239964.850               0.072

# %%
alt.Chart(cf_flowTypes).mark_bar(width=250).encode(
    alt.Y('sum(Amount (Constant USD2017)):Q', stack='normalize'),
    color='Flow Class:N'

).properties(width=600)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Apply OECD ODA-eligibility to Chinese data

# %%
eligible_countries.head()
# Out:
#                    ODA_eligible_country iso3code  numericISOcode eligibility
# 0                           Afghanistan      AFG           4.000         yes
# 1  Democratic Peoples Republic of Korea      PRK         408.000         yes
# 2                               Armenia      ARM          51.000         yes
# 3                               Albania      ALB           8.000         yes
# 4                                Angola      AGO          24.000         yes

# %%
countrycodesAidData = pd.read_csv('../data/country-and-continent-codes-list-forAidData.csv', delimiter=';')

# %%
cfm = cf.merge(countrycodesAidData[['country','ISO3code']], left_on='Recipient', right_on='country')

# %%
cfm.head()
# Out:
#    \AidData TUFF Project ID Recommended For Aggregates Umbrella  \
# 0                     53631                        Yes       No
# 1                     53632                        Yes       No
# 2                     53633                        Yes       No
# 3                     53634                        Yes       No
# 4                     53636                        Yes       No
#
#               Financier Country    Recipient Recipient Region  \
# 0  China (People's Republic of)  Afghanistan             Asia
# 1  China (People's Republic of)  Afghanistan             Asia
# 2  China (People's Republic of)  Afghanistan             Asia
# 3  China (People's Republic of)  Afghanistan             Asia
# 4  China (People's Republic of)  Afghanistan             Asia
#
#    Commitment Year                                              Title  \
# 0             2017  China provides humanitarian aid to Afghanistan...
# 1             2017       China donates equipment to Kabul University
# 2             2017  China donates $1 million USD to UNHCR for huma...
# 3             2017  Chinese Government provides RMB 180 million gr...
# 4             2017  China donates desks and chairs to China-Afghan...
#
#        Status            Intent Flow Type Concessional Flow Class  \
# 0  Completion       Development     Grant          Yes   ODA-like
# 1  Completion       Development     Grant          Yes   ODA-like
# 2  Completion       Development     Grant          Yes   ODA-like
# 3  Completion       Development     Grant          Yes   ODA-like
# 4  Completion  Representational     Grant          Yes   OOF-like
#
#    Sector Code         Sector Name  \
# 0          720  EMERGENCY RESPONSE
# 1          110           EDUCATION
# 2          720  EMERGENCY RESPONSE
# 3          110           EDUCATION
# 4          110           EDUCATION
#
#                              Funding Agencies Funding Agencies Type  \
# 0  Unspecified Chinese Government Institution     Government Agency
# 1  Unspecified Chinese Government Institution     Government Agency
# 2  Unspecified Chinese Government Institution     Government Agency
# 3                  China Ministry of Commerce     Government Agency
# 4                             Chinese Embassy     Government Agency
#
#    Amount (Original Currency) Original Currency  Amount (Constant USD2017)  \
# 0               137100000.000               AFN                2015410.812
# 1                         NaN               NaN                        NaN
# 2                 1000000.000               USD                1000000.000
# 3                18000000.000               CNY                2663728.108
# 4                         NaN               NaN                        NaN
#
#    Amount (Nominal)      country ISO3code
# 0       2015410.812  Afghanistan      AFG
# 1               NaN  Afghanistan      AFG
# 2       1000000.000  Afghanistan      AFG
# 3       2663728.108  Afghanistan      AFG
# 4               NaN  Afghanistan      AFG

# %%
cfmm = cfm.merge(eligible_countries, left_on='ISO3code',right_on='iso3code')

# %%
len(cfmm)
# Out:
# 9842

# %%
cfmm.head()
# Out:
#    \AidData TUFF Project ID Recommended For Aggregates Umbrella  \
# 0                     53631                        Yes       No
# 1                     53632                        Yes       No
# 2                     53633                        Yes       No
# 3                     53634                        Yes       No
# 4                     53636                        Yes       No
#
#               Financier Country    Recipient Recipient Region  \
# 0  China (People's Republic of)  Afghanistan             Asia
# 1  China (People's Republic of)  Afghanistan             Asia
# 2  China (People's Republic of)  Afghanistan             Asia
# 3  China (People's Republic of)  Afghanistan             Asia
# 4  China (People's Republic of)  Afghanistan             Asia
#
#    Commitment Year                                              Title  \
# 0             2017  China provides humanitarian aid to Afghanistan...
# 1             2017       China donates equipment to Kabul University
# 2             2017  China donates $1 million USD to UNHCR for huma...
# 3             2017  Chinese Government provides RMB 180 million gr...
# 4             2017  China donates desks and chairs to China-Afghan...
#
#        Status            Intent Flow Type Concessional Flow Class  \
# 0  Completion       Development     Grant          Yes   ODA-like
# 1  Completion       Development     Grant          Yes   ODA-like
# 2  Completion       Development     Grant          Yes   ODA-like
# 3  Completion       Development     Grant          Yes   ODA-like
# 4  Completion  Representational     Grant          Yes   OOF-like
#
#    Sector Code         Sector Name  \
# 0          720  EMERGENCY RESPONSE
# 1          110           EDUCATION
# 2          720  EMERGENCY RESPONSE
# 3          110           EDUCATION
# 4          110           EDUCATION
#
#                              Funding Agencies Funding Agencies Type  \
# 0  Unspecified Chinese Government Institution     Government Agency
# 1  Unspecified Chinese Government Institution     Government Agency
# 2  Unspecified Chinese Government Institution     Government Agency
# 3                  China Ministry of Commerce     Government Agency
# 4                             Chinese Embassy     Government Agency
#
#    Amount (Original Currency) Original Currency  Amount (Constant USD2017)  \
# 0               137100000.000               AFN                2015410.812
# 1                         NaN               NaN                        NaN
# 2                 1000000.000               USD                1000000.000
# 3                18000000.000               CNY                2663728.108
# 4                         NaN               NaN                        NaN
#
#    Amount (Nominal)      country ISO3code ODA_eligible_country iso3code  \
# 0       2015410.812  Afghanistan      AFG          Afghanistan      AFG
# 1               NaN  Afghanistan      AFG          Afghanistan      AFG
# 2       1000000.000  Afghanistan      AFG          Afghanistan      AFG
# 3       2663728.108  Afghanistan      AFG          Afghanistan      AFG
# 4               NaN  Afghanistan      AFG          Afghanistan      AFG
#
#    numericISOcode eligibility
# 0           4.000         yes
# 1           4.000         yes
# 2           4.000         yes
# 3           4.000         yes
# 4           4.000         yes

# %%
cf_odaEligible = cfmm[cfmm['eligibility']=='yes']

# %%
len(cf_odaEligible)
# Out:
# 9842

# %% [markdown]
# ### Unify unit: convert current prices to constant ones

# %%
# currentPrices_Million_USD_year * (CPI2017 / CPP_year)
# https://www.census.gov/topics/income-poverty/income/guidance/current-vs-constant-dollars.html
cpi_2017 = 361.0
cpi_2020 = 381.2
cpis = [{'year':2000, 'cpi':252.9},{'year':2001, 'cpi':260.1},{'year':2002, 'cpi':264.2},{'year':2003, 'cpi':270.2},{'year':2004, 'cpi':277.5},{'year':2005, 'cpi':286.9},{'year':2006, 'cpi':296.2},{'year':2007, 'cpi':304.6},{'year':2008, 'cpi':316.3},{'year':2009, 'cpi':315.2},{'year':2010, 'cpi':320.4},{'year':2011, 'cpi':330.5},{'year':2012, 'cpi':337.5},{'year':2013, 'cpi':342.5},{'year':2014, 'cpi':348.3},{'year': 2013, 'cpi': 342.5},{'year': 2014, 'cpi': 348.3},{'year': 2015, 'cpi': 348.9}, {'year': 2016, 'cpi': 353.4},{'year': 2017, 'cpi': 361.0}, {'year': 2018, 'cpi': 369.8}, {'year': 2019, 'cpi': 376.5}, {'year':2020, 'cpi': 381.2}]

cpidf = pd.DataFrame(cpis)
cpidf
# Out:
#     year     cpi
# 0   2000 252.900
# 1   2001 260.100
# 2   2002 264.200
# 3   2003 270.200
# 4   2004 277.500
# 5   2005 286.900
# 6   2006 296.200
# 7   2007 304.600
# 8   2008 316.300
# 9   2009 315.200
# 10  2010 320.400
# 11  2011 330.500
# 12  2012 337.500
# 13  2013 342.500
# 14  2014 348.300
# 15  2013 342.500
# 16  2014 348.300
# 17  2015 348.900
# 18  2016 353.400
# 19  2017 361.000
# 20  2018 369.800
# 21  2019 376.500
# 22  2020 381.200

# %% [markdown]
# ### Filter to include bilateraland multilateral donors

# %%
dfn = pd.read_csv('../data/OECD-SSA-OOF_ODA.csv')
dfn.head()
# Out:
#    year  Current Prices (USD millions) Flow Class            donor
# 0  2002                      17763.500        ODA  Official Donors
# 1  2003                      24288.163        ODA  Official Donors
# 2  2004                      27253.009        ODA  Official Donors
# 3  2005                      34326.733        ODA  Official Donors
# 4  2006                      81264.320        ODA  Official Donors

# %%
dfn_constant = pd.DataFrame()

for year in range(2002,2020,1):
    df_melted_temp = dfn[dfn['year']==year]
    cpi_year = cpidf[cpidf['year']==year]['cpi'].iloc[0]
    df_melted_temp['constant2020_million_USD'] = df_melted_temp['Current Prices (USD millions)'] * (cpi_2020/cpi_year)
    dfn_constant= pd.concat([dfn_constant,df_melted_temp])
# Out:
# /var/folders/fk/_qbrt9ys18b6s2yb_kqblv1xt9_xg3/T/ipykernel_13910/2631004586.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_melted_temp['constant2020_million_USD'] = df_melted_temp['Current Prices (USD millions)'] * (cpi_2020/cpi_year)

# %%
dfn_constant
# Out:
#     year  Current Prices (USD millions) Flow Class            donor  \
# 0   2002                      17763.500        ODA  Official Donors
# 18  2002                        215.279        OOF  Official Donors
# 1   2003                      24288.163        ODA  Official Donors
# 19  2003                        374.109        OOF  Official Donors
# 2   2004                      27253.009        ODA  Official Donors
# 20  2004                        408.078        OOF  Official Donors
# 3   2005                      34326.733        ODA  Official Donors
# 21  2005                        982.710        OOF  Official Donors
# 4   2006                      81264.320        ODA  Official Donors
# 22  2006                        579.062        OOF  Official Donors
# 5   2007                      35793.142        ODA  Official Donors
# 23  2007                        871.395        OOF  Official Donors
# 6   2008                      40499.046        ODA  Official Donors
# 24  2008                       1478.019        OOF  Official Donors
# 7   2009                      44238.366        ODA  Official Donors
# 25  2009                       3343.797        OOF  Official Donors
# 8   2010                      45851.392        ODA  Official Donors
# 26  2010                       2205.924        OOF  Official Donors
# 9   2011                      49340.472        ODA  Official Donors
# 27  2011                       3135.797        OOF  Official Donors
# 10  2012                      47257.182        ODA  Official Donors
# 28  2012                       3169.840        OOF  Official Donors
# 11  2013                      49248.227        ODA  Official Donors
# 29  2013                       2685.213        OOF  Official Donors
# 12  2014                      46790.215        ODA  Official Donors
# 30  2014                       3880.075        OOF  Official Donors
# 13  2015                      46528.478        ODA  Official Donors
# 31  2015                       3413.738        OOF  Official Donors
# 14  2016                      45210.882        ODA  Official Donors
# 32  2016                       3109.567        OOF  Official Donors
# 15  2017                      50421.769        ODA  Official Donors
# 33  2017                       5722.758        OOF  Official Donors
# 16  2018                      51677.086        ODA  Official Donors
# 34  2018                       4161.819        OOF  Official Donors
# 17  2019                      54235.247        ODA  Official Donors
# 35  2019                       5501.955        OOF  Official Donors
#
#     constant2020_million_USD
# 0                  25630.001
# 18                   310.614
# 1                  34265.906
# 19                   527.796
# 2                  37437.286
# 20                   560.574
# 3                  45609.448
# 21                  1305.713
# 4                 104584.601
# 22                   745.234
# 5                  44794.306
# 23                  1090.532
# 6                  48808.840
# 24                  1781.286
# 7                  53501.476
# 25                  4043.957
# 8                  54552.280
# 26                  2624.526
# 9                  56909.495
# 27                  3616.840
# 10                 53376.112
# 28                  3580.276
# 11                 54812.917
# 29                  2988.622
# 12                 51209.962
# 30                  4246.582
# 13                 50835.929
# 31                  3729.771
# 14                 48767.369
# 32                  3354.179
# 15                 53243.154
# 33                  6042.978
# 16                 53270.160
# 34                  4290.117
# 17                 54912.287
# 35                  5570.638

# %% [markdown]
# ### Same with Chineses data

# %%
cf_odaEligible.head()
# Out:
#    \AidData TUFF Project ID Recommended For Aggregates Umbrella  \
# 0                     53631                        Yes       No
# 1                     53632                        Yes       No
# 2                     53633                        Yes       No
# 3                     53634                        Yes       No
# 4                     53636                        Yes       No
#
#               Financier Country    Recipient Recipient Region  \
# 0  China (People's Republic of)  Afghanistan             Asia
# 1  China (People's Republic of)  Afghanistan             Asia
# 2  China (People's Republic of)  Afghanistan             Asia
# 3  China (People's Republic of)  Afghanistan             Asia
# 4  China (People's Republic of)  Afghanistan             Asia
#
#    Commitment Year                                              Title  \
# 0             2017  China provides humanitarian aid to Afghanistan...
# 1             2017       China donates equipment to Kabul University
# 2             2017  China donates $1 million USD to UNHCR for huma...
# 3             2017  Chinese Government provides RMB 180 million gr...
# 4             2017  China donates desks and chairs to China-Afghan...
#
#        Status            Intent Flow Type Concessional Flow Class  \
# 0  Completion       Development     Grant          Yes   ODA-like
# 1  Completion       Development     Grant          Yes   ODA-like
# 2  Completion       Development     Grant          Yes   ODA-like
# 3  Completion       Development     Grant          Yes   ODA-like
# 4  Completion  Representational     Grant          Yes   OOF-like
#
#    Sector Code         Sector Name  \
# 0          720  EMERGENCY RESPONSE
# 1          110           EDUCATION
# 2          720  EMERGENCY RESPONSE
# 3          110           EDUCATION
# 4          110           EDUCATION
#
#                              Funding Agencies Funding Agencies Type  \
# 0  Unspecified Chinese Government Institution     Government Agency
# 1  Unspecified Chinese Government Institution     Government Agency
# 2  Unspecified Chinese Government Institution     Government Agency
# 3                  China Ministry of Commerce     Government Agency
# 4                             Chinese Embassy     Government Agency
#
#    Amount (Original Currency) Original Currency  Amount (Constant USD2017)  \
# 0               137100000.000               AFN                2015410.812
# 1                         NaN               NaN                        NaN
# 2                 1000000.000               USD                1000000.000
# 3                18000000.000               CNY                2663728.108
# 4                         NaN               NaN                        NaN
#
#    Amount (Nominal)      country ISO3code ODA_eligible_country iso3code  \
# 0       2015410.812  Afghanistan      AFG          Afghanistan      AFG
# 1               NaN  Afghanistan      AFG          Afghanistan      AFG
# 2       1000000.000  Afghanistan      AFG          Afghanistan      AFG
# 3       2663728.108  Afghanistan      AFG          Afghanistan      AFG
# 4               NaN  Afghanistan      AFG          Afghanistan      AFG
#
#    numericISOcode eligibility
# 0           4.000         yes
# 1           4.000         yes
# 2           4.000         yes
# 3           4.000         yes
# 4           4.000         yes

# %% [markdown]
# ## Filter for ODA-like / OOF-like data

# %%
selection_cf = cf_odaEligible[(cf_odaEligible['Flow Class']=='ODA-like')|(cf_odaEligible['Flow Class']=='OOF-like')]

# %%
cf_grouped = selection_cf.groupby(by=['Recipient', 'Commitment Year', 'Flow Class', 'ISO3code'])['Amount (Constant USD2017)'].sum().reset_index()
cf_grouped
# Out:
#         Recipient  Commitment Year Flow Class ISO3code  \
# 0     Afghanistan             2000   ODA-like      AFG
# 1     Afghanistan             2001   ODA-like      AFG
# 2     Afghanistan             2002   ODA-like      AFG
# 3     Afghanistan             2003   ODA-like      AFG
# 4     Afghanistan             2004   ODA-like      AFG
# ...           ...              ...        ...      ...
# 2367     Zimbabwe             2014   OOF-like      ZWE
# 2368     Zimbabwe             2015   ODA-like      ZWE
# 2369     Zimbabwe             2015   OOF-like      ZWE
# 2370     Zimbabwe             2016   ODA-like      ZWE
# 2371     Zimbabwe             2017   ODA-like      ZWE
#
#       Amount (Constant USD2017)
# 0                   1113800.692
# 1                   2446247.143
# 2                  15609533.866
# 3                  14994850.208
# 4                  63438647.712
# ...                         ...
# 2367              186003981.060
# 2368               22904189.937
# 2369             1374669654.314
# 2370               29804740.570
# 2371               90753957.950
#
# [2372 rows x 5 columns]

# %% [markdown]
# ### rework cf data from Constant USD2017 to Constant USD2020

# %%
# currentPrice_year = constant price / (cpi_2017 /cpy_year) 
# constant price 2020 = currentPrice_year * (cpi_2020 /cpy_year)

# %%
cf_grouped_constant = pd.DataFrame()

for year in range(2000,2018,1):
    cf_grouped_temp = cf_grouped[cf_grouped['Commitment Year']==year]
    cpi_year = cpidf[cpidf['year']==year]['cpi'].iloc[0]
    cf_grouped_temp['currentPrices_Million_USD'] = cf_grouped_temp['Amount (Constant USD2017)'] / (cpi_2017 /cpi_year) /1000000
    cf_grouped_temp['constant2020_million_USD'] = cf_grouped_temp['currentPrices_Million_USD'] * (cpi_2020/cpi_year)
    cf_grouped_constant= pd.concat([cf_grouped_constant,cf_grouped_temp])
# Out:
# /var/folders/fk/_qbrt9ys18b6s2yb_kqblv1xt9_xg3/T/ipykernel_13910/927310507.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cf_grouped_temp['currentPrices_Million_USD'] = cf_grouped_temp['Amount (Constant USD2017)'] / (cpi_2017 /cpi_year) /1000000
# /var/folders/fk/_qbrt9ys18b6s2yb_kqblv1xt9_xg3/T/ipykernel_13910/927310507.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cf_grouped_temp['constant2020_million_USD'] = cf_grouped_temp['currentPrices_Million_USD'] * (cpi_2020/cpi_year)

# %%
cf_grouped_constant.head()
# Out:
#        Recipient  Commitment Year Flow Class ISO3code  \
# 0    Afghanistan             2000   ODA-like      AFG
# 22       Albania             2000   ODA-like      ALB
# 41       Algeria             2000   ODA-like      DZA
# 59        Angola             2000   ODA-like      AGO
# 146   Bangladesh             2000   ODA-like      BGD
#
#      Amount (Constant USD2017)  currentPrices_Million_USD  \
# 0                  1113800.692                      0.780
# 22                 2673121.661                      1.873
# 41                       0.000                      0.000
# 59                       0.000                      0.000
# 146              145215208.830                    101.731
#
#      constant2020_million_USD
# 0                       1.176
# 22                      2.823
# 41                      0.000
# 59                      0.000
# 146                   153.341

# %% [markdown]
# ### Development of donations to each recipient over time

# %%
cf_grouped_constant.head()
# Out:
#        Recipient  Commitment Year Flow Class ISO3code  \
# 0    Afghanistan             2000   ODA-like      AFG
# 22       Albania             2000   ODA-like      ALB
# 41       Algeria             2000   ODA-like      DZA
# 59        Angola             2000   ODA-like      AGO
# 146   Bangladesh             2000   ODA-like      BGD
#
#      Amount (Constant USD2017)  currentPrices_Million_USD  \
# 0                  1113800.692                      0.780
# 22                 2673121.661                      1.873
# 41                       0.000                      0.000
# 59                       0.000                      0.000
# 146              145215208.830                    101.731
#
#      constant2020_million_USD
# 0                       1.176
# 22                      2.823
# 41                      0.000
# 59                      0.000
# 146                   153.341

# %%
regions = pd.read_csv('../data/country-and-continent-codes-list.csv', delimiter=';')
regions.head()
# Out:
#   continent            region         subregion         country  numericISO  \
# 0      Asia     Southern Asia     Southern Asia     Afghanistan       4.000
# 1    Europe   Southern Europe   Southern Europe         Albania       8.000
# 2  Americas  Northern America  Northern America      Antarctica      10.000
# 3    Africa   Northern Africa   Northern Africa         Algeria      12.000
# 4   Oceania         Polynesia         Polynesia  American Samoa      16.000
#
#   ISO3code ISO2code otherGroups
# 0      AFG       AF    LDC LLDC
# 1      ALB       AL         NaN
# 2      ATA       AQ         NaN
# 3      DZA       DZ         NaN
# 4      ASM       AS        SIDS

# %%
cf_grouped_constant_m= cf_grouped_constant.merge(regions[['ISO3code', 'region']], left_on='ISO3code', right_on='ISO3code')

# %%
cf_grouped_constant_m.head()
# Out:
#      Recipient  Commitment Year Flow Class ISO3code  \
# 0  Afghanistan             2000   ODA-like      AFG
# 1  Afghanistan             2001   ODA-like      AFG
# 2  Afghanistan             2002   ODA-like      AFG
# 3  Afghanistan             2003   ODA-like      AFG
# 4  Afghanistan             2004   ODA-like      AFG
#
#    Amount (Constant USD2017)  currentPrices_Million_USD  \
# 0                1113800.692                      0.780
# 1                2446247.143                      1.763
# 2               15609533.866                     11.424
# 3               14994850.208                     11.223
# 4               63438647.712                     48.765
#
#    constant2020_million_USD         region
# 0                     1.176  Southern Asia
# 1                     2.583  Southern Asia
# 2                    16.483  Southern Asia
# 3                    15.834  Southern Asia
# 4                    66.988  Southern Asia

# %%
cf_grouped_constant_m_ssa = cf_grouped_constant_m[cf_grouped_constant_m['region']=='Sub-Saharan Africa']

# %%
cftimeline = cf_grouped_constant_m_ssa.groupby(by=['Commitment Year','Flow Class'])['constant2020_million_USD'].sum().reset_index()
cftimeline.head()
# Out:
#    Commitment Year Flow Class  constant2020_million_USD
# 0             2000   ODA-like                   259.309
# 1             2000   OOF-like                   158.405
# 2             2001   ODA-like                  2105.367
# 3             2001   OOF-like                    93.570
# 4             2002   ODA-like                   704.148

# %%
cftimeline['year_parsed']=pd.to_datetime(cftimeline['Commitment Year'], format='%Y')

# %%
alt.Chart(cftimeline).mark_bar().encode(
    alt.Color('Flow Class', scale = alt.Scale(domain=['ODA-like','OOF-like'], range=['#00A5FF','#002D5A'])),
    x='year_parsed:T',
    y='sum(constant2020_million_USD)',

)
# Out:
# alt.Chart(...)

# %%
dfn_constant['year_parsed']=pd.to_datetime(dfn_constant['year'], format='%Y')

# %%
alt.Chart(dfn_constant).mark_bar().encode(
    alt.Color('Flow Class', scale = alt.Scale(domain=['ODA','OOF'], range=['#00A5FF','#002D5A'])),
    x='year_parsed:T',
    y='sum(constant2020_million_USD)',

)
# Out:
# alt.Chart(...)
